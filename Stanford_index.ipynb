# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import os

# %%
print("yolo let's go")
# Out:
# yolo let's go

# %%
path = "C:/Users/titou/Desktop/Centrale/Option OSY/RI-W/pa1-data (1)/pa1-data/"
path_2 = "C:/Users/titou/Desktop/Centrale/Option OSY/RI-W/Stanford_treated/"

# %%
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words('english'))
wl = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\titou\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\titou\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#Dictionnaries to build
dico_termID = {} #{term:termID}
dico_docID = {} #{doc:docID}
dico_index = {} #{termID:docID}
docID = 0 #initialisation of docIDs
termID = 0 #initialisation of termIDs

# %%
for i in range(0,9): #Browsing blocks
    path_temp = path + str(i) + "/"
    for root,dirs,files in os.walk(path_temp):
        for file in files:
            filename = str(i)+file
            dico_docID[docID] = filename
            
            
            with open(path_temp + file, 'r') as f:
                for line in f.readlines():
                    
                    #Stop words
                    wordList = line.split()
                    wordList_filtered = [w for w in wordList if not w in stop_words]
                    
                    #Lemmatisation
                    wordList_filtered = list(map(wl.lemmatize,wordList_filtered))
                    
                    #Construction de l'index
                    #termID
                    for w in wordList_filtered:
                        dico_termID[termID] = w
                        dico_index[termID] = docID
                        termID += 1
                  
            docID += 1 #Next document
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-39c3356b6a7c> in <module>()
#      20                     #termID
#      21                     for w in wordList_filtered:
# ---> 22                         dico_termID[termID] = w
#      23                         dico_index[termID] = docID
#      24                         termID += 1
#
# MemoryError:

# %%
i=0
path_temp = path + str(i) + "/"
for root,dirs,files in os.walk(path_temp):
    for file in files:
        filename = str(i)+file
        dico_docID[docID] = filename


        with open(path_temp + file, 'r') as f:
            for line in f.readlines():

                #Stop words
                wordList = line.split()
                wordList_filtered = [w for w in wordList if not w in stop_words]

                #Lemmatisation
                wordList_filtered = list(map(wl.lemmatize,wordList_filtered))

                #Construction de l'index
                #termID
                for w in wordList_filtered:
                    dico_termID[termID] = w
                    dico_index[termID] = docID
                    termID += 1

        docID += 1 #Next document

# %%
print(docID)
print(termID)
# Out:
# 7957
# 1615106

# %%
print(dico_docID)
# Out:
# {0: '03dradiology.stanford.edu_patient_care_Case%2520studies_AVM.html', 1: '03dradiology.stanford.edu_patient_care_case_studies.html', 2: '05-sure.stanford.edu_', 3: '050years.stanford.edu_', 4: '0a3cservices.stanford.edu_awards_nominate_', 5: '0a3cservices.stanford.edu_facilities_', 6: '0a3cservices.stanford.edu_lead_', 7: '0aa.stanford.edu_', 8: '0aa.stanford.edu_about_aviation.php', 9: '0aa.stanford.edu_about_computation.php', 10: '0aa.stanford.edu_about_control.php', 11: '0aa.stanford.edu_about_space.php', 12: '0aa.stanford.edu_about_structure.php', 13: '0aa.stanford.edu_admissions_', 14: '0aa.stanford.edu_admissions_admittedGrad.php', 15: '0aa.stanford.edu_admissions_assistantApplication.php', 16: '0aa.stanford.edu_admissions_assistantsAero.php', 17: '0aa.stanford.edu_admissions_currentStudents.php', 18: '0aa.stanford.edu_admissions_fellowsAero.php', 19: '0aa.stanford.edu_admissions_pdfs_application_form2011.pdf', 20: '0aa.stanford.edu_affiliates_index.php', 21: '0aa.stanford.edu_contact_index.php', 22: '0aa.stanford.edu_curriculum_coterm.php', 23: '0aa.stanford.edu_curriculum_courses.php', 24: '0aa.stanford.edu_curriculum_engineerAero.php', 25: '0aa.stanford.edu_curriculum_index.php', 26: '0aa.stanford.edu_curriculum_undergraduate.php', 27: '0aa.stanford.edu_events_50thAnniversary_media_AlSaud.pdf', 28: '0aa.stanford.edu_events_50thAnniversary_media_Ying.pdf', 29: '0aa.stanford.edu_events_50thAnniversary_program.php', 30: '0aa.stanford.edu_events_affiliatesMeeting_affiliates2004meeting.php', 31: '0aa.stanford.edu_events_affiliatesMeeting_affiliates2005meeting.php', 32: '0aa.stanford.edu_events_affiliatesMeeting_affiliatesmeeting.php', 33: '0aa.stanford.edu_events_awards_awardballhaus.php', 34: '0aa.stanford.edu_events_awards_awardCA.php', 35: '0aa.stanford.edu_events_awards_awardcannon.php', 36: '0aa.stanford.edu_events_awards_awardhoff.php', 37: '0aa.stanford.edu_events_awards_awardstaff.php', 38: '0aa.stanford.edu_events_awards_awardstanaway.php', 39: '0aa.stanford.edu_events_commencementAcadProc.php', 40: '0aa.stanford.edu_events_commencementAwards_commencementAwards.php', 41: '0aa.stanford.edu_events_commencementAwards_commencementAwards2003.php', 42: '0aa.stanford.edu_events_commencementAwards_commencementAwards2004.php', 43: '0aa.stanford.edu_events_commencementAwards_commencementAwards2005.php', 44: '0aa.stanford.edu_events_commencementAwards_commencementAwards2006.php', 45: '0aa.stanford.edu_events_commencementAwards_commencementAwards2007.php', 46: '0aa.stanford.edu_events_commencementAwards_commencementAwards2008.php', 47: '0aa.stanford.edu_events_commencementAwards_commencementAwards2009.php', 48: '0aa.stanford.edu_events_commencementAwards_commencementAwards2010.php', 49: '0aa.stanford.edu_events_commencementSchedule.php', 50: '0aa.stanford.edu_events_orientation.php', 51: '0aa.stanford.edu_events_visitday.php', 52: '0aa.stanford.edu_faculty_facultyProfiles.php', 53: '0aa.stanford.edu_faculty_facultySearch.php', 54: '0aa.stanford.edu_faculty_researchSummaries.php', 55: '0aa.stanford.edu_giving_index.php', 56: '0aa.stanford.edu_index.html', 57: '0aa.stanford.edu_news_brysonAward.php', 58: '0aa.stanford.edu_news_changSPIEAward.php', 59: '0aa.stanford.edu_news_farhatAward.php', 60: '0aa.stanford.edu_news_gaoAward.php', 61: '0aa.stanford.edu_news_hubbardCommittee.php', 62: '0aa.stanford.edu_news_krooChair.php', 63: '0aa.stanford.edu_news_marcoPavoneAppointed.php', 64: '0aa.stanford.edu_news_NRC.php', 65: '0aa.stanford.edu_news_parkinsonAward.php', 66: '0aa.stanford.edu_news_sigridCloseAppointed.php', 67: '0aa.stanford.edu_news_subramanianBradleyAward.php', 68: '0aa.stanford.edu_news_tsaiSAMPEFellow.php', 69: '0aa.stanford.edu_students_graduates_graduates.php', 70: '0aa.stanford.edu_students_graduates_graduates2002.php', 71: '0aa.stanford.edu_students_graduates_graduates2004.php', 72: '0aa.stanford.edu_students_graduates_graduates2005.php', 73: '0aa.stanford.edu_students_graduates_graduates2006.php', 74: '0aa.stan ...

# %%
import operator

def shuffle_order(tuple_list):
    a = sorted(tuple_list, key = operator.itemgetter(0))
    return a

l = [('b',2),('a',1),('d',5),('c',3)]
# l = [(2,2),(4,1),(3,5),(1,3)]
# l = [4,6,2,4,7,2]
# l.sort()
# print(l)

print(shuffle_order(l))
# Out:
# [('a', 1), ('b', 2), ('c', 3), ('d', 5)]
# [('a', 1), ('b', 2), ('c', 3), ('d', 5)]
